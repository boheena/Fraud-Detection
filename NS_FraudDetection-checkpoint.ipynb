# %% [markdown]
# <center><h1><font color="orange">Finastra Interview: Fraud Detection</font></h1></center>

# %% [markdown]
# <h4>Background:</h4>
# <p>Credit card companies need to recognize fraudulent credit card transactions for the security of their customers and to ensure their customers are not liable for items they did not purchase.</p>
#
# <h4>Data:</h4>
# The dataset in the zip file contains credit card transactions from European cardholders during the time period of September 2013 over the course of two days. <p>There are 492/284,807 transactions that are fraudulent, which is a highly unbalanced dataset. The feature descriptions are as follows:</p>
#
# <ul>
#     <li><b>Time:</b> The number of seconds that elapsed between this transaction and the first transaction in the dataset</li>
#     <li><b>V1-V28:</b> PCA transformed features to hide confidental information of the user</li>
#     <li><b>Amount:</b> The transaction amount</li>
#     <li><b>Class:</b> 1 if a fraudulent transaction, 0 if not a fraudulent transaction.</li>
# </ul>
#
# <h4>Goal:</h4>
# <p>Your goal is to build a model that predicts if a transaction is fraudulent or not. We want to see how you explore the data, get insights into the data, visualize the data, choose features, select models, tune parameters, and evaluate model performance.</p>
#
# <h4>Tips:</h4>
# <p>Below are some tips/questions to solve:</p>
# <ul>
#     <li>How do you perform classification on a highly unbalanced dataset like this?</li>
#     <li>Would you use classification? Anomaly detection? The approach is up to you!</li>
#     <li>What methods can you use for feature selection? Is there a model you can build to get feature importances? Can you look at correlations between features?</li>
#     <li>What kind of train/test set will you use?</li>
#     <li>What performance metrics can you show besides pure accuracy?</li>
#     <li>Use the mark down cells to explain functions you write and what you are doing in your code.</li>
# </ul>

# %% [markdown]
# <h4>Imports:</h4>
# <p>List the imports you use in the project here, you can use any library you want.</p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils import resample
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# <h4>Load Data:</h4>

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %% [markdown]
# # Explore the data

# %%
df.info()
#no missing values for
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %%
#get basic information of each columns
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
print(df['Class'].value_counts())
df['Class'].value_counts().plot(kind='bar')
#find out is an imbalanced data
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
plt.figure(figsize=(16,16))
corr = df.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns,linewidths=.1,cmap="Blues")
plt.show()

# %% [markdown]
# ## Decision Tree and Random Forest Classification

# %%
# apply decision tree to the unbalanced data
feature = ['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17',
          'V18', 'V19', 'V20', 'V21','V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28']
df['Amount'] = StandardScaler().fit_transform(df['Amount'].values.reshape(-1,1))
X = df[feature]
y = df.Class

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state = 1)

tree = DecisionTreeClassifier()

tree.fit(X_train,y_train)

y_tree_pred = tree.predict(X_test)

# %%
print('Tree Score is', tree.score(X_test, y_test))

print('Tree accuracy is', metrics.accuracy_score(y_test, y_tree_pred))

print('Tree precision score is', metrics.precision_score(y_test, y_tree_pred))

print('Tree recall score is ', metrics.recall_score(y_test, y_tree_pred))

print('Tree F1 score is ', metrics.f1_score(y_test, y_tree_pred))

print(metrics.confusion_matrix(y_test, y_tree_pred))
# Out:
# Tree Score is 0.9991807499648893
# Tree accuracy is 0.9991807499648893
# Tree precision score is 0.7575757575757576
# Tree recall score is  0.7246376811594203
# Tree F1 score is  0.7407407407407408
# [[42637    16]
#  [   19    50]]

# %%
# use cross validation 5 folds on Random Forest
random_forest = RandomForestClassifier(n_estimators=70, random_state=0)

random_forest.fit(X_train, y_train)

y_random_forest_pred = random_forest.predict(X_test)

#F1_scores = cross_val_score(random_forest, X, y, cv=5, scoring = 'f1')

# %%
# print scores for random forest classification
print('Random forest classification Score is', random_forest.score(X_test, y_test))

print('Random forest classification accuracy is', metrics.accuracy_score(y_test, y_random_forest_pred))

print('Random forest classification precision score is', metrics.precision_score(y_test, y_random_forest_pred))

print('Ramdom forest recall score is', metrics.recall_score(y_test, y_random_forest_pred))

print('Random forest f1 score is', metrics.f1_score(y_test, y_random_forest_pred))

print(metrics.confusion_matrix(y_test, y_random_forest_pred))

fpr_rf, tpr_rf, _rf = metrics.roc_curve(y_test, y_random_forest_pred)

plt.plot(fpr_rf, tpr_rf)
plt.title('ROC for Random Forest')
plt.xlabel('Fales Positive Rate')
plt.ylabel('True Positiove Rate')
plt.show()
# Out:
# Random forest classification Score is 0.9995318571227939
# Random forest classification accuracy is 0.9995318571227939
# Random forest classification precision score is 0.9454545454545454
# Ramdom forest recall score is 0.7536231884057971
# Random forest f1 score is 0.8387096774193549
# [[42650     3]
#  [   17    52]]

# %% [markdown]
# ### Feature Selection (Random Forest)

# %%
random_forest_feature_importances = pd.DataFrame(random_forest.feature_importances_,index = X.columns, columns=['importance'])

print(random_forest_feature_importances.sort_values('importance', ascending=False))
# Out:
#      importance
# V17    0.197780
# V12    0.161157
# V14    0.092381
# V10    0.081755
# V11    0.059116
# V16    0.058355
# V9     0.038923
# V7     0.028419
# V18    0.026723
# V4     0.026214
# V26    0.018806
# V21    0.016932
# V3     0.016422
# V1     0.014892
# V6     0.014448
# V27    0.014137
# V15    0.013887
# V20    0.012850
# V2     0.012368
# V19    0.012256
# V24    0.011501
# V5     0.011326
# V13    0.010970
# V8     0.010587
# V22    0.010348
# V28    0.010219
# V25    0.009521
# V23    0.007706

# %% [markdown]
# # Using Down-Sampling

# %%
# down-sampling the non-fraud data, but would casue a huge information loss

df_non_fraud = df[df.Class == 0]
df_fraud = df[df.Class == 1]

# df_non_fraud['Class'].value_counts()

df_non_fraud_downsample = resample(df_non_fraud, replace=False, n_samples=492, random_state=42)

# df_non_fraud_downsample['Class'].value_counts()

# Combine non-fraud and fraud data together 
df_downsample = pd.concat([df_non_fraud_downsample, df_fraud])

print(df_downsample['Class'].value_counts())
# Out:
# 1    492
# 0    492
# Name: Class, dtype: int64

# %% [markdown]
# ## Logistic Regression

# %%
#normolize amount

X_downsample = df_downsample[feature]
y_downsample = df_downsample.Class
X_ds_train, X_ds_test, y_ds_train, y_ds_test = train_test_split(X_downsample, y_downsample, test_size = 0.3, random_state = 42)

# %%
penalty = ['l1', 'l2']
C = np.logspace(0, 4, 10)
hyperparameters = dict(C=C, penalty=penalty)

lr = LogisticRegression()
lr_best = GridSearchCV(lr, hyperparameters, cv=5, verbose=0)
best_model = lr_best.fit(X_ds_train, y_ds_train)
y_lr_pred = best_model.predict(X_ds_test)

print('Best Penalty:', best_model.best_estimator_.get_params()['penalty'])
print('Best C:', best_model.best_estimator_.get_params()['C'])
# Out:
# C:\Users\bohan\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\bohan\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\bohan\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\bohan\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
print('logistic Regreeion Score is', best_model.score(X_ds_test, y_ds_test))

print('logistic regreesion accuracy is', metrics.accuracy_score(y_ds_test, y_lr_pred))

print('logistic regreesion precision score is', metrics.precision_score(y_ds_test, y_lr_pred))

print('logistic regreesion recall score is ', metrics.recall_score(y_ds_test, y_lr_pred))

print('logistic regreesion F1 score is ', metrics.f1_score(y_ds_test, y_lr_pred))

print(metrics.confusion_matrix(y_ds_test, y_lr_pred))

fpr_lr, tpr_lr, threadhold_lr = metrics.roc_curve(y_ds_test, y_lr_pred)

plt.plot(fpr_lr, tpr_lr)
plt.title('ROC for Logistic Regression')
plt.xlabel('Fales Positive Rate')
plt.ylabel('True Positiove Rate')
plt.show()
# Out:
# logistic Regreeion Score is 0.9222972972972973
# logistic regreesion accuracy is 0.9222972972972973
# logistic regreesion precision score is 0.948905109489051
# logistic regreesion recall score is  0.8904109589041096
# logistic regreesion F1 score is  0.9187279151943463
# [[143   7]
#  [ 16 130]]
